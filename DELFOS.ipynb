# %% [markdown]
# <a href="https://colab.research.google.com/github/Seung-heon-Baek/DELFOS/blob/main/DELFOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MoreiraLAB/delfos.git
# Out:
# Cloning into 'delfos'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 117 (delta 52), reused 53 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 8.92 MiB | 12.28 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Filtering content: 100% (2/2), 382.38 MiB | 53.48 MiB/s, done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# mamba 사용하여 환경 생성
# !mamba create --name delfos python=3.9 r-base=4.2 -y

# 환경 활성화 (Colab에서는 mamba activate가 작동하지 않으므로, 직접 python 실행)
# !source activate delfos && python --version && R --version
# Out:
# Looking for: ['python=3.9', 'r-base=4.2']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   1%
# conda-forge/noarch     3%[+] 0.3s
# conda-forge/linux-64   3%
# conda-forge/noarch     7%[+] 0.4s
# conda-forge/linux-64   5%
# conda-forge/noarch    15%[+] 0.5s
# conda-forge/linux-64   7%
# conda-forge/noarch    18%[+] 0.6s
# conda-forge/linux-64  10%
# conda-forge/noarch    24%[+] 0.7s
# conda-forge/linux-64  11%
# conda-forge/noarch    28%[+] 0.8s
# conda-forge/linux-64  11%
# conda-forge/noarch    31%[+] 0.9s
# conda-forge/linux-64  14%
# conda-forge/noarch    32%[+] 1.0s
# conda-forge/linux-64  15%
# conda-forge/noarch    37%[+] 1.1s
# conda-forge/linux-64  17%
# conda-forge/noarch    39%[+] 1.2s
# conda-forge/linux-64  20%
# conda-forge/noarch    47%[+] 1.3s
# conda-forge/linux-64  22%
# conda-forge/noarch    52%[+] 1.4s
# conda-forge/linux-64  25%
# ...

# %%
# !pip install -r /content/delfos/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 50.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.11 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0)
# ERROR: No matching distribution found for tensorflow==2.11

# %%
# mamba 환경에 numpy 설치
# !mamba install -n delfos numpy -y
# Out:
# Looking for: ['numpy']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.9.*
#
#
# Transaction
#
#   Prefix: /usr/local/envs/delfos
#
#   All requested packages already installed

# %%
# mamba 환경에 pandas 설치
# !mamba install -n delfos pandas -y
# Out:
# Looking for: ['pandas']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.9.*
#
#
# Transaction
#
#   Prefix: /usr/local/envs/delfos
#
#   Updating specs:
#
#    - pandas
#    - ca-certificates
#    - openssl
#
#
#   Package                Version  Build           Channel           Size
# ──────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────
#
#   + python-tzdata         2025.1  pyhd8ed1ab_0    conda-forge      144kB
#   + pytz                  2024.1  pyhd8ed1ab_0    conda-forge     Cached
#   + six                   1.17.0  pyhd8ed1ab_0    conda-forge     Cached
#   + python-dateutil  2.9.0.post0  pyhff2d567_1    conda-forge     Cached
#   + pandas                 2.2.3  py39h3b40f6f_2  conda-forge     Cached
#
#   Summary:
#
# ...

# %%
# !mamba install -n delfos -c conda-forge pubchempy -y
# Out:
# Looking for: ['pubchempy']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.9.*
#
#
# Transaction
#
#   Prefix: /usr/local/envs/delfos
#
#   Updating specs:
#
#    - pubchempy
#    - ca-certificates
#    - openssl
#
#
#   Package      Version  Build         Channel         Size
# ────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────
#
#   + pubchempy    1.0.4  pyhd8ed1ab_1  conda-forge     19kB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 19kB
#
# ────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# ...
# Extracting         0%pubchempy                                           19.0kB @ 208.0kB/s  0.1s
# [+] 0.1s
# ...
# Extracting   (1)  ⣾
# ...
#
# done
# done
# done

# %%
# delfos 환경에서 0_prepare_data.py 실행
# !source activate delfos && python /content/delfos/scripts/0_prepare_data.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/envs/delfos/lib/python3.9/site-packages/pubchempy.py", line 271, in request
#     response = urlopen(apiurl, postdata)
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 523, in open
#     response = meth(req, response)
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 632, in http_response
#     response = self.parent.error(
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 561, in error
#     return self._call_chain(*args)
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/usr/local/envs/delfos/lib/python3.9/urllib/request.py", line 641, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# ...
